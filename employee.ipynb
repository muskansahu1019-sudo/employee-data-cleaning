# %%
import pandas as pd
cleaned_data = df.copy()
df=pd.read_csv("Messy_Employee_dataset.csv")
print(df.columns)
# Out:
# Index(['Employee_ID', 'First_Name', 'Last_Name', 'Age', 'Department_Region',
#        'Status', 'Join_Date', 'Salary', 'Email', 'Phone', 'Performance_Score',
#        'Remote_Work'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# Employee_ID            0
# First_Name             0
# Last_Name              0
# Age                  211
# Department_Region      0
# Status                 0
# Join_Date              0
# Salary                24
# Email                  0
# Phone                  0
# Performance_Score      0
# Remote_Work            0
# dtype: int64

# %%
age_mean=df["Age"].mean()
cleaned_data=df.copy()
age_mean=cleaned_data["Age"].mean()
cleaned_data["Age"]=cleaned_data["Age"].fillna(age_mean)
print(cleaned_data["Age"])
# Out:
# 0       25.000000
# 1       32.484549
# 2       32.484549
# 3       25.000000
# 4       25.000000
#           ...
# 1015    30.000000
# 1016    30.000000
# 1017    40.000000
# 1018    30.000000
# 1019    30.000000
# Name: Age, Length: 1020, dtype: float64

# %%
print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1015    False
# 1016    False
# 1017    False
# 1018    False
# 1019    False
# Length: 1020, dtype: bool

# %%
df2=df.copy()
print(df2.drop_duplicates(inplace=True))
# Out:
# None

# %%
print(pd.to_datetime(df["Join_Date"]))
# Out:
# 0      2021-04-02
# 1      2020-07-10
# 2      2023-12-07
# 3      2021-11-27
# 4      2022-01-05
#           ...
# 1015   2023-08-19
# 1016   2021-11-07
# 1017   2023-10-04
# 1018   2024-12-16
# 1019   2021-02-22
# Name: Join_Date, Length: 1020, dtype: datetime64[ns]

# %%
print(pd.to_numeric(df["Phone"]))
# Out:
# 0      -1651623197
# 1      -1898471390
# 2      -5596363211
# 3      -3476490784
# 4      -1586734256
#            ...
# 1015   -3546212759
# 1016   -2508261122
# 1017   -1261632487
# 1018   -8995729892
# 1019   -7629745492
# Name: Phone, Length: 1020, dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        1020 non-null   object
#  1   First_Name         1020 non-null   object
#  2   Last_Name          1020 non-null   object
#  3   Age                809 non-null    float64
#  4   Department_Region  1020 non-null   object
#  5   Status             1020 non-null   object
#  6   Join_Date          1020 non-null   object
#  7   Salary             996 non-null    float64
#  8   Email              1020 non-null   object
#  9   Phone              1020 non-null   int64
#  10  Performance_Score  1020 non-null   object
#  11  Remote_Work        1020 non-null   bool
# dtypes: bool(1), float64(2), int64(1), object(8)
# memory usage: 88.8+ KB
# None

# %%
print(df["Salary"].round(0))
sal_mean=df["Salary"].mean()
cleaned_data=df.copy()
sal_mean=cleaned_data["Salary"].mean()
cleaned_data["Salary"]=cleaned_data["Salary"].fillna(sal_mean).round(0)
print(cleaned_data["Salary"])
# Out:
# 0        59768.0
# 1        65305.0
# 2        88146.0
# 3        69451.0
# 4       109325.0
#           ...
# 1015         NaN
# 1016    100215.0
# 1017    114587.0
# 1018     71319.0
# 1019     77764.0
# Name: Salary, Length: 1020, dtype: float64
# 0        59768
# 1        65305
# 2        88146
# 3        69451
# 4       109325
#          ...
# 1015     85155
# 1016    100215
# 1017    114587
# 1018     71319
# 1019     77764
# Name: Salary, Length: 1020, dtype: int64

# %%
print(cleaned_data["Salary"].astype(int))
# Out:
# 0        59767
# 1        65304
# 2        88145
# 3        69450
# 4       109324
#          ...
# 1015     85155
# 1016    100215
# 1017    114587
# 1018     71318
# 1019     77764
# Name: Salary, Length: 1020, dtype: int64

# %%
print(cleaned_data["Salary"].dtype)
# Out:
# float64

# %%
df.to_csv("employee_data_cleaned.csv",index=False)

# %%
print(df.head())
# Out:
#   Employee_ID First_Name Last_Name   Age   Department_Region    Status  \
# 0     EMP1000        Bob     Davis  25.0   DevOps-California    Active
# 1     EMP1001        Bob     Brown   NaN       Finance-Texas    Active
# 2     EMP1002      Alice     Jones   NaN        Admin-Nevada   Pending
# 3     EMP1003        Eva     Davis  25.0        Admin-Nevada  Inactive
# 4     EMP1004      Frank  Williams  25.0  Cloud Tech-Florida    Active
#
#     Join_Date     Salary                       Email       Phone  \
# 0    4/2/2021   59767.65       bob.davis@example.com -1651623197
# 1   7/10/2020   65304.66       bob.brown@example.com -1898471390
# 2   12/7/2023   88145.90     alice.jones@example.com -5596363211
# 3  11/27/2021   69450.99       eva.davis@example.com -3476490784
# 4    1/5/2022  109324.61  frank.williams@example.com -1586734256
#
#   Performance_Score  Remote_Work
# 0           Average         True
# 1         Excellent         True
# 2              Good         True
# ...

# %%
age_mean=df["Age"].mean()
cleaned_data=df.copy()
age_mean=cleaned_data["Age"].mean()
cleaned_data["Age"]=cleaned_data["Age"].fillna(age_mean)
print(cleaned_data["Age"])
df2=df.copy()
print(df2.drop_duplicates(inplace=True))
print(pd.to_datetime(df["Join_Date"]))
print(pd.to_numeric(df["Phone"]))
print(df["Salary"].round(0))
sal_mean=df["Salary"].mean()
cleaned_data=df.copy()
sal_mean=cleaned_data["Salary"].mean()
cleaned_data["Salary"]=cleaned_data["Salary"].fillna(sal_mean).round(0)
print(cleaned_data["Salary"])
print(cleaned_data["Salary"].astype(int))
cleaned_data.to_csv("employee_cleaned_data.csv",index=False)
# Out:
# 0       25.000000
# 1       32.484549
# 2       32.484549
# 3       25.000000
# 4       25.000000
#           ...
# 1015    30.000000
# 1016    30.000000
# 1017    40.000000
# 1018    30.000000
# 1019    30.000000
# Name: Age, Length: 1020, dtype: float64
# None
# 0      2021-04-02
# 1      2020-07-10
# 2      2023-12-07
# 3      2021-11-27
# 4      2022-01-05
#           ...
# 1015   2023-08-19
# 1016   2021-11-07
# 1017   2023-10-04
# 1018   2024-12-16
# 1019   2021-02-22
# Name: Join_Date, Length: 1020, dtype: datetime64[ns]
# 0      -1651623197
# 1      -1898471390
# 2      -5596363211
# 3      -3476490784
# 4      -1586734256
#            ...
# 1015   -3546212759
# 1016   -2508261122
# 1017   -1261632487
# 1018   -8995729892
# 1019   -7629745492
# Name: Phone, Length: 1020, dtype: int64
# 0        59768.0
# 1        65305.0
# 2        88146.0
# 3        69451.0
# 4       109325.0
#           ...
# 1015         NaN
# 1016    100215.0
# 1017    114587.0
# 1018     71319.0
# ...

# %%
print(df.head())
# Out:
#   Employee_ID First_Name Last_Name   Age   Department_Region    Status  \
# 0     EMP1000        Bob     Davis  25.0   DevOps-California    Active
# 1     EMP1001        Bob     Brown   NaN       Finance-Texas    Active
# 2     EMP1002      Alice     Jones   NaN        Admin-Nevada   Pending
# 3     EMP1003        Eva     Davis  25.0        Admin-Nevada  Inactive
# 4     EMP1004      Frank  Williams  25.0  Cloud Tech-Florida    Active
#
#     Join_Date     Salary                       Email       Phone  \
# 0    4/2/2021   59767.65       bob.davis@example.com -1651623197
# 1   7/10/2020   65304.66       bob.brown@example.com -1898471390
# 2   12/7/2023   88145.90     alice.jones@example.com -5596363211
# 3  11/27/2021   69450.99       eva.davis@example.com -3476490784
# 4    1/5/2022  109324.61  frank.williams@example.com -1586734256
#
#   Performance_Score  Remote_Work
# 0           Average         True
# 1         Excellent         True
# 2              Good         True
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID            0
# First_Name             0
# Last_Name              0
# Age                  211
# Department_Region      0
# Status                 0
# Join_Date              0
# Salary                24
# Email                  0
# Phone                  0
# Performance_Score      0
# Remote_Work            0
# dtype: int64

# %%
df["Age"].unique()
df["Salary"].unique()
# Out:
# array([ 59767.65,  65304.66,  88145.9 ,  69450.99, 109324.61,  88642.84,
#         96288.43,  94497.91, 115565.82,  76561.88,  72081.71,  84946.19,
#         89295.77,  85666.84,  97633.68, 117975.49,  94867.33, 100377.65,
#         94726.46,  91926.12, 111460.67,  96182.56, 115023.94,  80667.01,
#         91181.61,  66025.92,  83979.01,  56785.16,  95741.88,  63411.31,
#        111214.02, 114845.69,  78072.82,  79610.52,  90542.62, 114357.1 ,
#         54757.26,  52781.92,  66708.02,  93481.15,  59271.96, 108362.15,
#         59400.38,  64744.08,  94399.91,  61310.74,  98371.37,  58921.19,
#         57195.55,  61375.12, 104767.05, 111051.67, 105674.18,  54859.45,
#        115746.6 ,  91759.99, 112965.33, 100360.1 ,  93620.88,  72832.8 ,
#        102369.42,  64712.79,  85782.18,  93348.26,  53234.96, 100284.21,
#        112486.19,  82518.49, 119152.47, 113479.83,  94636.3 ,  70000.97,
#         76812.47,  82614.7 , 111645.97, 112414.91,  52031.74,  51887.65,
# ...

# %%
df["Salary"].dtype
# Out:
# dtype('float64')

# %%
sal_mean=df["Salary"].mean()
cleaned_data=df.copy()
sal_mean=cleaned_data["Salary"].mean()
cleaned_data["Salary"]=cleaned_data["Salary"].fillna(sal_mean).round(0)
print(cleaned_data["Salary"])
print(cleaned_data["Salary"].astype(int))
# Out:
# 0        59768.0
# 1        65305.0
# 2        88146.0
# 3        69451.0
# 4       109325.0
#           ...
# 1015     85155.0
# 1016    100215.0
# 1017    114587.0
# 1018     71319.0
# 1019     77764.0
# Name: Salary, Length: 1020, dtype: float64
# 0        59768
# 1        65305
# 2        88146
# 3        69451
# 4       109325
#          ...
# 1015     85155
# 1016    100215
# 1017    114587
# 1018     71319
# 1019     77764
# Name: Salary, Length: 1020, dtype: int64

# %%
import pandas as pd
df=pd.read_csv("Messy_Employee_dataset.csv")
cleaned_data = df.copy()
print(df.columns)
age_mean=cleaned_data["Age"].mean()
cleaned_data["Age"]=cleaned_data["Age"].fillna(age_mean)
cleaned_data["Age"] = cleaned_data["Age"].round(0).astype(int)
print(cleaned_data["Age"])
cleaned_data = cleaned_data.drop_duplicates()
cleaned_data["Join_Date"] = pd.to_datetime(cleaned_data["Join_Date"])
cleaned_data["Phone"] = pd.to_numeric(cleaned_data["Phone"])
sal_mean=cleaned_data["Salary"].mean()
cleaned_data["Salary"] = cleaned_data["Salary"].fillna(sal_mean).round(0).astype(int)
# Out:
# Index(['Employee_ID', 'First_Name', 'Last_Name', 'Age', 'Department_Region',
#        'Status', 'Join_Date', 'Salary', 'Email', 'Phone', 'Performance_Score',
#        'Remote_Work'],
#       dtype='object')
# 0       25
# 1       32
# 2       32
# 3       25
# 4       25
#         ..
# 1015    30
# 1016    30
# 1017    40
# 1018    30
# 1019    30
# Name: Age, Length: 1020, dtype: int64

# %%
print(cleaned_data.isnull().sum())
print(cleaned_data.info())
# Out:
# Employee_ID          0
# First_Name           0
# Last_Name            0
# Age                  0
# Department_Region    0
# Status               0
# Join_Date            0
# Salary               0
# Email                0
# Phone                0
# Performance_Score    0
# Remote_Work          0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        1020 non-null   object
#  1   First_Name         1020 non-null   object
#  2   Last_Name          1020 non-null   object
#  3   Age                1020 non-null   int64
#  4   Department_Region  1020 non-null   object
#  5   Status             1020 non-null   object
#  6   Join_Date          1020 non-null   datetime64[ns]
#  7   Salary             1020 non-null   int64
#  8   Email              1020 non-null   object
# ...

# %%
cleaned_data.to_csv("employee_cleaned_data.csv", index=False)
